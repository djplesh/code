# %%
m,s=100000, .05
d = np.random.normal(m,s,1000)

# %%
d
# Out:
# array([ 100000.02236293,   99999.9714286 ,  100000.01036558,
#          99999.98299169,   99999.97889565,  100000.05078818,
#          99999.96509919,   99999.95234555,  100000.02181055,
#          99999.98379935,  100000.00625598,  100000.06180884,
#          99999.91508044,  100000.00466055,   99999.95545219,
#          99999.94413464,  100000.03378071,   99999.94427157,
#         100000.12346389,  100000.11109437,  100000.05062286,
#         100000.12309454,  100000.02229434,  100000.01204066,
#         100000.04308023,   99999.96827059,   99999.96523731,
#         100000.02608929,  100000.00364464,   99999.84097738,
#          99999.99475416,   99999.99228381,   99999.9544068 ,
#         100000.06445472,   99999.94807659,  100000.0155713 ,
#         100000.07443016,   99999.94219712,  100000.04227912,
#         100000.03659971,  100000.05192514,   99999.94024798,
#          99999.99056091,   99999.95723993,   99999.97455201,
# ...

# %%
from scipy.stats import norm

# %%
(mu,sig) = norm.fit(d)

# %%
mu
# Out:
# 99999.99760790063

# %%
sig
# Out:
# 0.04948649330366077

# %%
1.428*2.355
# Out:
# 3.36294
