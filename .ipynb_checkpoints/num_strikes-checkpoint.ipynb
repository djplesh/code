# %%
import tetra_analysis.ec_search.lightning as light
import datetime as dt
import time
import urllib2
from urllib2 import HTTPError

# %%
'''print the number of nearby strikes for a given date/loc'''

loop_date = dt.date(2018, 1, 1)
end_date = dt.date(2018, 6, 1)
source = ['entln']
locations = ['LSU','PAN','PR','UAH']

while loop_date < end_date + dt.timedelta(1):
    for loc in locations:
        for s in source:
            x = light.nearby(loc, loop_date, s)
            if len(x[0]) > 0:
                print len(x[0]), 'strikes', loc, loop_date, s
    loop_date += dt.timedelta(1)
# Out:
# 51 strikes PAN 2018-01-02
# 3 strikes PAN 2018-01-05
# 14 strikes PAN 2018-01-06
# 42 strikes LSU 2018-01-08
# 4 strikes PAN 2018-01-14
# 1 strikes PAN 2018-01-17
# 31 strikes PAN 2018-01-18
# 66 strikes LSU 2018-01-22
# 39 strikes PAN 2018-01-22
# 10 strikes LSU 2018-01-27
# 2 strikes LSU 2018-02-04
# 1 strikes LSU 2018-02-06
# 1 strikes LSU 2018-02-07
# 1 strikes PR 2018-02-13
# 3 strikes PR 2018-02-25
# 49 strikes LSU 2018-02-26
# 1 strikes PR 2018-02-26
# 12 strikes LSU 2018-03-06
# 126 strikes LSU 2018-03-11
# 1 strikes UAH 2018-03-11
# 19 strikes UAH 2018-03-17
# 2 strikes LSU 2018-03-18
# 5 strikes UAH 2018-03-19
# 1 strikes UAH 2018-03-20
# 2 strikes PR 2018-03-26
# 5 strikes PR 2018-03-27
# 1 strikes LSU 2018-03-29
# 3 strikes LSU 2018-04-04
# 7 strikes PR 2018-04-04
# 5 strikes UAH 2018-04-04
# 9 strikes PAN 2018-04-06
# 159 strikes LSU 2018-04-07
# 110 strikes PAN 2018-04-12
# 6 strikes PAN 2018-04-13
# 293 strikes LSU 2018-04-14
# 7 strikes PAN 2018-04-14
# 18 strikes UAH 2018-04-14
# 37 strikes PAN 2018-04-16
# 1 strikes PR 2018-04-16
# 12 strikes PR 2018-04-17
# 1 strikes PAN 2018-04-20
# 5 strikes PAN 2018-04-21
# 109 strikes PR 2018-04-21
# 12 strikes PAN 2018-04-22
# 14 strikes UAH 2018-04-22
# 43 strikes PAN 2018-04-23
# 1 strikes LSU 2018-04-26
# 65 strikes PAN 2018-04-26
# 84 strikes PAN 2018-04-27
# 70 strikes PAN 2018-04-29
# 24 strikes PAN 2018-04-30
# 28 strikes PAN 2018-05-03
# 32 strikes PAN 2018-05-04
# 2 strikes PAN 2018-05-05
# 11 strikes PAN 2018-05-06
# 30 strikes PAN 2018-05-07
# 7 strikes UAH 2018-05-07
# 2 strikes PAN 2018-05-09
# 2 strikes PAN 2018-05-11
# 10 strikes LSU 2018-05-12
# 117 strikes LSU 2018-05-14
# 2 strikes PAN 2018-05-14
# 305 strikes LSU 2018-05-15
# 144 strikes UAH 2018-05-15
# 9 strikes PAN 2018-05-16
# 10 strikes UAH 2018-05-16
# 5 strikes PAN 2018-05-17
# 717 strikes LSU 2018-05-18
# 45 strikes PAN 2018-05-18
# 1 strikes LSU 2018-05-19
# 1 strikes PAN 2018-05-19
# 2 strikes PAN 2018-05-20
# 94 strikes UAH 2018-05-20
# 7 strikes LSU 2018-05-22
# 1 strikes UAH 2018-05-22
# 512 strikes LSU 2018-05-23
# 3 strikes LSU 2018-05-25
# 74 strikes UAH 2018-05-25
# 30 strikes LSU 2018-05-26
# 26 strikes PAN 2018-05-26
# 2 strikes PR 2018-05-26
# 1 strikes UAH 2018-05-26
# 3 strikes PR 2018-05-27
# 20 strikes UAH 2018-05-27
# 3 strikes LSU 2018-05-28
# 43 strikes UAH 2018-05-28

# %%
'''print the number of nearby strikes for a given date/loc'''

loop_date = dt.date(2018, 1, 1)
end_date = dt.date(2018, 6, 1)
source = ['wwlln']
locations = ['LSU','PAN','PR','UAH']

while loop_date < end_date + dt.timedelta(1):
    for loc in locations:
        for s in source:
            x = light.nearby(loc, loop_date, s)
            if len(x[0]) > 0:
                print len(x[0]), 'strikes', loc, loop_date
    loop_date += dt.timedelta(1)
# Out:
# 8 strikes PAN 2018-01-01
# 32 strikes PAN 2018-01-02
# 1 strikes PAN 2018-01-04
# 3 strikes PAN 2018-01-05
# 10 strikes PAN 2018-01-06
# 34 strikes LSU 2018-01-08
# 1 strikes PAN 2018-01-13
# 6 strikes PAN 2018-01-14
# 3 strikes PAN 2018-01-17
# 17 strikes PAN 2018-01-18
# 24 strikes LSU 2018-01-22
# 9 strikes PAN 2018-01-22
# 10 strikes LSU 2018-01-27
# 7 strikes LSU 2018-02-06
# 4 strikes PR 2018-02-25
# 10 strikes LSU 2018-02-26
# 3 strikes PR 2018-02-27
# 11 strikes LSU 2018-03-06
# 16 strikes LSU 2018-03-11
# 5 strikes UAH 2018-03-17
# 2 strikes UAH 2018-03-19
# 2 strikes UAH 2018-03-20
# 1 strikes PAN 2018-03-23
# 4 strikes PR 2018-03-26
# 2 strikes PR 2018-03-27
# 3 strikes LSU 2018-04-04
# 8 strikes PR 2018-04-04
# 4 strikes PAN 2018-04-06
# 154 strikes LSU 2018-04-07
# 87 strikes PAN 2018-04-12
# 11 strikes PAN 2018-04-13
# 88 strikes LSU 2018-04-14
# 2 strikes PAN 2018-04-14
# 4 strikes UAH 2018-04-14
# 25 strikes PAN 2018-04-16
# 2 strikes PR 2018-04-16
# 1 strikes PAN 2018-04-17
# 8 strikes PR 2018-04-17
# 2 strikes PR 2018-04-18
# 1 strikes PR 2018-04-20
# 6 strikes PAN 2018-04-21
# 56 strikes PR 2018-04-21
# 7 strikes PAN 2018-04-22
# 4 strikes UAH 2018-04-22
# 21 strikes PAN 2018-04-23
# 1 strikes UAH 2018-04-23
# 49 strikes PAN 2018-04-26
# 46 strikes PAN 2018-04-27
# 15 strikes PAN 2018-04-29
# 18 strikes PAN 2018-04-30
# 16 strikes PAN 2018-05-03
# 16 strikes PAN 2018-05-04
# 1 strikes PAN 2018-05-05
# 5 strikes PAN 2018-05-06
# 14 strikes PAN 2018-05-07
# 2 strikes PAN 2018-05-10
# 1 strikes PAN 2018-05-11
# 7 strikes LSU 2018-05-12
# 1 strikes PAN 2018-05-13
# 1 strikes LSU 2018-05-14
# 17 strikes LSU 2018-05-15
# 3 strikes UAH 2018-05-15
# 3 strikes PAN 2018-05-16
# 3 strikes PAN 2018-05-17
# 50 strikes LSU 2018-05-18
# 24 strikes PAN 2018-05-18
# 3 strikes LSU 2018-05-19
# 1 strikes PAN 2018-05-19
# 1 strikes PAN 2018-05-20
# 4 strikes UAH 2018-05-20
# 2 strikes LSU 2018-05-22
# 1 strikes PAN 2018-05-22
# 87 strikes LSU 2018-05-23
# 7 strikes PAN 2018-05-23
# 3 strikes LSU 2018-05-24
# 1 strikes PAN 2018-05-24
# 1 strikes LSU 2018-05-25
# 7 strikes UAH 2018-05-25
# 3 strikes LSU 2018-05-26
# 33 strikes PAN 2018-05-26
# 3 strikes PR 2018-05-27
# 3 strikes UAH 2018-05-27
# 5 strikes UAH 2018-05-28
# 4 strikes PAN 2018-05-30
# 1 strikes UAH 2018-05-30
# 17 strikes PAN 2018-05-31
# 8 strikes UAH 2018-05-31

# %%
'''compare wwlln and entln strikes'''

window = 1
loop_date = dt.date(2018, 5, 26)
end_date = dt.date(2018, 5, 26)
source = ['boltek', 'entln']
locations = ['LSU']
while loop_date < end_date + dt.timedelta(1):
    for loc in locations:
        strikes = {}
        for s in source:
            x = light.nearby(loc, loop_date, s)
            if len(x[0]) > 0:
                strikes[s] = x[0]
        match_num = 0
        if len(strikes['boltek']) + len(strikes['entln']) > 0:
            for l in strikes['entln']:
                diffs = np.abs(l-strikes['boltek'])
                matches = np.where(diffs <= window)[0]
                if len(matches) > 0:
                    match_num +=1
            if match_num > 0:
                print loc, str(loop_date)
                print str(match_num) + ' out of ' + str(len(strikes['entln'])) + ' strikes matched within ' + str(window) + ' seconds'
    loop_date += dt.timedelta(1)
# Out:
#  LSU 2018-05-26
# 2 out of 30 strikes matched within 1 seconds

# %%
'''plot time histogram of strikes within 8 kilometers'''

d = dt.date(2018, 5, 26)
loc = 'LSU'
source = ['boltek']
for s in source:
    x = light.nearby(loc, d, s)
    bins = np.linspace(0, 86400, 1441)
    plt.hist(x[0], bins, histtype='step', color = 'black')
    plt.title(str(d) + ' ' + s)
    plt.ylabel('Flashes/sec')
    plt.xlabel('UTC Time (sec)')
    plt.show()

# %%
'''plot strikes vs distance'''

start_time = time.time()
d = dt.date(2018, 5, 26)
loc = 'LSU'
source = ['boltek']
for s in source:
    method = {'wwlln':light.wwlln,'entln':light.entln,'boltek':light.boltek}
    x = method[s](d, loc)
    plt.plot(x[0], x[1], lw = 0, marker = '.', color = 'black')
    plt.ylim(0, 10)
    plt.xlim(0, 86400)
    plt.ylabel("Distance (km)")
    plt.xlabel("UTC Time (sec)")
    plt.title(s + ' all lightning strikes')
    plt.show()

# %%
'''read in boltek data from http://fisica.uprb.edu/pub/ '''

loc = 'LSU'
d = dt.date(2018, 5, 26)
plot = 'yes' # 'yes' or 'no'

date_str = d.strftime("%Y%m%d")

if loc == 'LSU': 
    serve = 'LLDN'
    filenames = ['LSU-Tetra2-LDN-', 'SU-Tetra-', 'MSA-Tetra-', 'Zack-Tetra-', 'LIGO-Tetra-']   
if loc == 'PR': 
    serve = 'PRLDN'
    filenames = ['PRLDN-Ponce-', 'PRLDN-Cayey-', 'PRLDN-Bayamon-', 'PRLDN-Arecibo-', 'PRLDN-Utuado-']
    
strikes = {}
for f in filenames:
    if loc == 'LSU': key = f.split('-')[0]
    if loc == 'PR': key = f.split('-')[-2]
    try:
        data = urllib2.urlopen("http://fisica.uprb.edu/pub/" + serve + "/" + f + date_str + ".txt").read()
    except HTTPError:
        continue
    data = data.split("\n")
    data = data[:-1]
    s = []
    for line in data:
        x = line.split()
        s.append(x[0])
    s = s[:-1]
    s = lightning.get_times(s)
    strikes[key] = s

if plot == 'no':
    for k in strikes.keys():
        print str(len(strikes[k])) + ' strikes detected by boltek antenna at ' + k

if plot == 'yes':
    bins = np.linspace(0,86400,86401)
    for k in strikes.keys():
        x = plt.hist(strikes[k], bins, histtype='step', color='black')
        plt.xlim([0,86400])
        plt.title(k)
        plt.ylabel('lightning strikes per second')
        plt.xlabel('UTC Time in seconds')
        plt.show()
# Out:
# 67434.0 UTC sees most strikes
# 73907.0 UTC sees most strikes
# 66982.0 UTC sees most strikes
# 72722.0 UTC sees most strikes
# 76683.0 UTC sees most strikes

# %%
#get wwlln data for Jonah
#save a file with 'YYYY-MM-DD' \t 'hh:mm:ss.sssss' \t lat \t lon

import tetra_tools.tools as tool
import tetra_analysis.ec_search.lightning as light
import csv

d = dt.date(2018, 5, 26)
loc = 'LSU'

lats, lons, times, dates, dists = [], [], [], [], []

d_str = d.strftime("%Y%m%d")
filename0 = 'C:/Users/tetra/lightning/WWLLN/'
folder = d.strftime("%Y_%m")
fname = 'C:/Users/tetra/lightning/WWLLN/{0}/AE{1}.loc'.format(folder, d_str)
if not os.path.isfile(fname):
    fname = 'C:/Users/tetra/lightning/WWLLN/{0}/A{1}.loc'.format(folder, d_str)
if not os.path.isfile(fname):
    pass
det_pos = tool.det_location(loc)

try:
    f = open(fname)
except NameError:
    pass
except IOError:
    pass
strikes_raw = []
for line in f:
    strikes_raw.append(line)
f.close()

for s in strikes_raw:
    lat = float(s.split(',')[2])
    lon = float(s.split(',')[3])
    if np.abs(lat - det_pos[0]) <= 2 and np.abs(lon - det_pos[1]) <= 2:
        lats.append(lat)
        lons.append(lon)
        times.append(s.split(',')[1])
        dates.append(s.split(',')[0])
dists = light.get_dists(lats, lons, det_pos)
        
lats2, lons2, times2, dates2 = [], [], [], []
for i in range(len(dists)):
    if dists[i] <= 8:
        lats2.append(lats[i])
        lons2.append(lons[i])
        times2.append(times_str[i])
        dates2.append(date_str2[i])
print len(lats2)

    
strikes_all2 = zip(dates2, times2, lats2, lons2)
with open('C:/Users/tetra/lightning/test.txt', 'w') as f:
    writer = csv.writer(f, delimiter='\t')
    writer.writerows(strikes_all2)
# Out:
# 3

# %%
#get entln data for Jonah
#save a file with 'YYYY-MM-DD' \t 'hh:mm:ss.sssss' \t lat \t lon

import tetra_tools.tools as tool
import tetra_analysis.ec_search.lightning as light
import csv

d = dt.date(2018, 5, 26)
loc = 'LSU'

lats, lons, times, dates, dists = [], [], [], [], []


folder = 'C:/Users/tetra/lightning/ENTLN/{0}/'.format(loc)
d_int = int(d.strftime("%Y%m%d"))
d_str = d.strftime("%Y-%m-%d")
det_pos = tool.det_location(loc)


for f in os.listdir(folder):
    if d_int > int(f[0:8]) and d_int < int(f[12:20]):
        fname = folder + f
        with open(fname, 'rb') as infile:
            temp = csv.reader(infile)
            for row in temp:
                if row[1] == 'timestamp':
                    continue
                # sp included because in some files there is an extra space 
                # before the date
                sp = 0
                if row[1][0] == ' ': sp = 1
                if row[1][0 + sp:10 + sp] == d_str:
                    lats.append(row[2])
                    lons.append(row[3])
                    times.append(row[1][11+sp:])
                    dates.append(row[1][0 + sp:10 + sp])
        dists = light.get_dists(lats, lons, det_pos)
        
lats2, lons2, times2, dates2 = [], [], [], []
for i in range(len(dists)):
    if dists[i] <= 8:
        lats2.append(lats[i])
        lons2.append(lons[i])
        times2.append(times_str[i])
        dates2.append(date_str2[i])

    
strikes_all2 = zip(dates2, times2, lats2, lons2)
with open('C:/Users/tetra/lightning/entln20180526.txt', 'w') as f:
    writer = csv.writer(f, delimiter='\t')
    writer.writerows(strikes_all2)

# %%
times2
# Out:
# ['14:03:17.567183495', '19:49:33.440309525', '19:49:59.203768730']
