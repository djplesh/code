# %%
import tetra_analysis.energy.spectra as spec

# %%
fp = "C:/Users/tetra/test1/"
box = "LSU_01"
dev = "Dev1"

# %%
labr = spec.labr_adc(fp,box,dev,0)

# %%
labr.keys()
# Out:
# ['Dev1_1', 'Dev1_3', 'Dev1_2']

# %%
for k in labr.keys():
    y = plt.hist(labr[k],np.linspace(1,2**15,1001))
    plt.xlim(0,33000)
    plt.ylim(0, 1000)
    plt.show()

# %%
cpd = spec.get_cpd(fp,0)
cpd_sum = cpd['pmt1'][0] + cpd['pmt2'][0]

# %%
plt.hist(cpd_sum,1000)
plt.xlim(0,2**15)
plt.ylim(0,200)
plt.show()

# %%
bgo = spec.bgo_adc(fp,dev,0)
# Out:
# C:\Anaconda2\lib\site-packages\scipy\stats\stats.py:305: RuntimeWarning: divide by zero encountered in log
#   log_a = np.log(np.array(a, dtype=dtype))
# C:\Anaconda2\lib\site-packages\scipy\stats\stats.py:305: RuntimeWarning: invalid value encountered in log
#   log_a = np.log(np.array(a, dtype=dtype))

# %%
for k in bgo.keys():
    test = bgo[k][~np.isnan(bgo[k])]
    y = plt.hist(test,np.linspace(1,2**15,1001))
    plt.xlim(0,33000)
    plt.ylim(0, 500)
    plt.show()

# %%
files = spec.adc_files(fp, 'Dev1')
gps = spec.pyTDMS4_analog(files, [6])
y = plt.hist(gps, np.linspace(1,2**15,1001))
plt.xlim(0, 7000)
plt.ylim(0, 2000)
print np.sum(np.array(y[0][100:]))
plt.show()
# Out:
# 7200.0

# %%
7200/12
# Out:
# 600
